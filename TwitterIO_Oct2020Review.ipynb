# %% [markdown]
# # Twitter's Information Operation Dataset Review
#
# The purpose of the analysis is to review October's 2020 dataset release from Twitters Information Operation's Transparency Center. Accounts in this dataset have been identifed by Twitter as accounts tied to platform manipulation tied to government or state-backed actor. This activity is considered an information operation and is against Twitter's policy.
#
# October's 2020 data includes accounts tied to the following regions:
# - Iran
# - Russia
# - Thailand
# - Saudi Arabia
# - Cuba
#
# Each region consist of the following dataset:
#
# - tweets_csv_hashed.zip - all tweets and metadata
# - users_csv_hashed.zip - list of users and profile metadata
# - media_file_list_hashed.txt - this files includes the list URLs, there are a number of .zip files where each contains a number of users' tweet media (Number of .zip files varies based on the volume of media
#
# The analysis below will review the users_csv and the tweets_csv file to answer the following questions:
#
# - The average number of followers for these accounts.
# - The average number of accounts these malicious accounts were following back.
# - The max/min number of followers for these accounts.
# - The max/min number of accounts these malicious accounts were following back.
# - The most popular month and year these accounts were created.
# - A profile review of the account with the most followers.

# %%
import pandas as pd
import glob
import datetime as dt
# combine all csv's into one dataframe

path = r'/Users/latoya/Desktop/twitter/'
all_files = glob.glob(path + "*.csv")

data = []

for f in all_files:
    
    df = pd.read_csv(f, index_col=None, header=0)
    data.append(df)

final = pd.concat(data, axis=0, ignore_index=True)

print("Original data and column information:\n")


print('dataset info')

print(final.info())
# Out:
# Original data and column information:
#
# dataset info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1594 entries, 0 to 1593
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   userid                    1594 non-null   object
#  1   user_display_name         1594 non-null   object
#  2   user_screen_name          1594 non-null   object
#  3   user_reported_location    381 non-null    object
#  4   user_profile_description  812 non-null    object
#  5   user_profile_url          83 non-null     object
#  6   follower_count            1594 non-null   int64
#  7   following_count           1594 non-null   int64
#  8   account_creation_date     1594 non-null   object
#  9   account_language          1594 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 124.7+ KB
# None

# %%
#changing creation_date column to datetime dtype

final['account_creation_date'] = final['account_creation_date'].astype('datetime64')

#new datetime dtype
print("Columns with changed data type for account_creation_date:\n")
final.info()
# Out:
# Columns with changed data type for account_creation_date:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1594 entries, 0 to 1593
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   userid                    1594 non-null   object
#  1   user_display_name         1594 non-null   object
#  2   user_screen_name          1594 non-null   object
#  3   user_reported_location    381 non-null    object
#  4   user_profile_description  812 non-null    object
#  5   user_profile_url          83 non-null     object
#  6   follower_count            1594 non-null   int64
#  7   following_count           1594 non-null   int64
#  8   account_creation_date     1594 non-null   datetime64[ns]
#  9   account_language          1594 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 124.7+ KB

# %%
#Creation of new column with just month and year

copy = final

dy = copy['account_creation_date']

copy['month_year_creation'] = dy.dt.strftime('%B %Y')

print("Updated data with new column just containing month and year of creation:")
print(copy.info())
# Out:
# Updated data with new column just containing month and year of creation:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1594 entries, 0 to 1593
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   userid                    1594 non-null   object
#  1   user_display_name         1594 non-null   object
#  2   user_screen_name          1594 non-null   object
#  3   user_reported_location    381 non-null    object
#  4   user_profile_description  812 non-null    object
#  5   user_profile_url          83 non-null     object
#  6   follower_count            1594 non-null   int64
#  7   following_count           1594 non-null   int64
#  8   account_creation_date     1594 non-null   datetime64[ns]
#  9   account_language          1594 non-null   object
#  10  month_year_creation       1594 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 137.1+ KB
# None

# %% [markdown]
# ## Analysis
#
# - The average number of followers for these accounts.
#     - The average number of followers these accounts had were 1,892.
#
# - The average number of accounts these malicious accounts were following back.
#     - The average number of accounts these accounts followed back were 810
#
# - The max/min number of followers for these accounts.
#     - The min/max number of followers these accounts had were 0/1,197,574
#
# - The max/min number of accounts these malicious accounts were following back.
#     - The min/max number accounts these accounts were following back were: 0 / 206,563
#
# - The most popular month and year these accounts were created.
#     - January 2019 and December 2020
#
# - A profile review of the account with the most followers.
#     - User Screen Name: fahad1althani
#     - Account Created: July 2013
#     - Account Language: Arabic
#     - Follower Count: 1,197,574
#     - Country: Saudi Arabia

# %%
'''Calculation of various trends for accounts included in dataset'''

avg_follower = copy['follower_count'].mean()
min_follower = copy['follower_count'].min()    
max_follower = copy['follower_count'].max()
avg_following=copy['following_count'].mean()
min_following=copy['following_count'].min()    
max_following = copy['following_count'].max()

print("Avg followers:",avg_follower)
print("Lowest followers:",min_follower)
print("Maximum followers:", max_follower)

print("Avg following:",avg_following)
print("Lowest following:",min_following)
print("Maximum following:", max_following)
um_mask = copy['follower_count'] == max_follower



language_counts = copy['account_language'].value_counts()


top_20_months = copy['month_year_creation'].value_counts().head(20)

print("\nlanguage counts\n",language_counts,"\n")

print("top 20 year and months:\n", top_20_months)

print("\nMost Popular Account:")

most_pop= copy.loc[um_mask]

print(most_pop[['user_screen_name','month_year_creation','account_language','follower_count','user_display_name']])
# Out:
# Avg followers: 1892.3036386449185
# Lowest followers: 0
# Maximum followers: 1197574
# Avg following: 810.2528230865746
# Lowest following: 0
# Maximum following: 206563
#
# language counts
#  en       940
# es       382
# th       252
# ar        17
# zh-cn      2
# ro         1
# Name: account_language, dtype: int64
#
# top 20 year and months:
#  January 2020      512
# December 2019     361
# February 2020     103
# April 2019         58
# November 2019      57
# September 2019     39
# February 2019      35
# April 2020         33
# March 2020         29
# March 2019         29
# June 2019          29
# October 2019       26
# July 2019          19
# August 2019        14
# May 2019           13
# May 2020           11
# September 2015     10
# September 2018      9
# December 2018       8
# June 2018           7
# Name: month_year_creation, dtype: int64
#
# Most Popular Account:
#    user_screen_name month_year_creation account_language  follower_count  \
# 15    fahad1althani           July 2013               ar         1197574
#
#          user_display_name
# 15  فهد بن عبدالله آل ثاني

# %%
''' Below will review the most popular profile outlined above to identify it's most popular tweet '''

tweets = pd.read_csv('qatar_tweets.csv',index_col=None, header=0)

user = 'fahad1althani'
print(tweets.info())

mask = tweets['user_screen_name'] == user

profile = tweets[mask]

print(profile.shape)

hashtags = profile['hashtags']

#mask_2 = hashtags != '[]'
print(profile.head(1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1,4,6,15,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220254 entries, 0 to 220253
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   tweetid                   220254 non-null  int64
#  1   userid                    220254 non-null  object
#  2   user_display_name         220254 non-null  object
#  3   user_screen_name          220254 non-null  object
#  4   user_reported_location    25015 non-null   object
#  5   user_profile_description  217903 non-null  object
#  6   user_profile_url          2913 non-null    object
#  7   follower_count            220254 non-null  int64
#  8   following_count           220254 non-null  int64
#  9   account_creation_date     220254 non-null  object
#  10  account_language          220254 non-null  object
#  11  tweet_language            219959 non-null  object
#  12  tweet_text                220254 non-null  object
#  13  tweet_time                220254 non-null  object
#  14  tweet_client_name         220254 non-null  object
#  15  in_reply_to_userid        5882 non-null    object
#  16  in_reply_to_tweetid       5647 non-null    float64
#  17  quoted_tweet_tweetid      2413 non-null    float64
#  18  is_retweet                220254 non-null  bool
#  19  retweet_userid            6848 non-null    object
#  20  retweet_tweetid           163470 non-null  float64
#  21  latitude                  220254 non-null  object
#  22  longitude                 220254 non-null  object
#  23  quote_count               220254 non-null  int64
#  24  reply_count               220254 non-null  int64
#  25  like_count                220254 non-null  int64
#  26  retweet_count             220254 non-null  int64
#  27  hashtags                  182240 non-null  object
#  28  urls                      181716 non-null  object
#  29  user_mentions             220254 non-null  object
# dtypes: bool(1), float64(3), int64(7), object(19)
# memory usage: 48.9+ MB
# None
# (1735, 30)
#                    tweetid      userid       user_display_name  \
# 73041  1006596199422550017  1594355905  فهد بن عبدالله آل ثاني
#
#       user_screen_name user_reported_location  \
# 73041    fahad1althani               دولة قطر
#
#                                 user_profile_description  \
# 73041  الحساب الرسمي | نسعى لتأسيس " قطر الجديدة " عل...
#
#               user_profile_url  follower_count  following_count  \
# 73041  https://t.co/kikksWNNC9         1197574               99
#
#       account_creation_date  ... retweet_tweetid latitude longitude  \
# 73041            2013-07-14  ...    1.006583e+18   absent    absent
#
#       quote_count reply_count like_count  retweet_count            hashtags  \
# 73041           0           0          0              0  ['قطري', 'العمرة']
#
#        urls  user_mentions
# 73041    []  ['510686970']
#
# [1 rows x 30 columns]

# %%
'''Instalation of google translator libery to aid in translation of tweet data'''
#!pip install google_trans_new
# Out:
# Collecting google_trans_new
#   Downloading google_trans_new-1.1.9-py3-none-any.whl (9.2 kB)
# Installing collected packages: google-trans-new
# Successfully installed google-trans-new-1.1.9

# %%
from google_trans_new import google_translator  

translator = google_translator()

n_empty = hashtags != '[]'#to disregard tweets without hashtags



f_hashtags = hashtags[n_empty]

hash_list = list(f_hashtags.unique()) 

translated =[]

for i in hash_list:
    translated.append(translator.translate(i))


# print(hashtags_translated)

# %%
#Translated hashtags


for i in translated:
       print(i)
        


print(test)
# Out:
# ['Qatari', 'Umrah']
# ['The Hamdeen Organization', 'Preventing Qataris from Umrah']
# ['Qatari', 'The Boycott', 'The Gulf', 'The Hamdeen Organization']
# ['The Hamdeen_ terrorist organization', 'Saudi Arabia', 'Al-Houthi', 'the mullahs' regime, 'Iran', 'Qatar']
# ['Forgiveness',' Meet_Fahd_al_2_twitter '')
# ['Iran', 'Tamim_Ben_Hamad', 'Saudi Arabia', 'Emirates', 'Hamdan_Terrorist Organization', 'Qatar']
# ['Al-Udeid Base', 'Tamim', 'Qatar', 'Al-Arabiya']
# ['Meet_Fahd_al_second_twitter' ')
# ['Qatar']
# ['King Abdulaziz_Label Festival', 'Qatar', 'Doha', 'Saudi Arabia']
# ['Abdullah
# ['Qatar', 'Qatar', 'Doha']
# ['National_Qatari Day', 'Qatar', 'Good news', 'Tamim drains Qatar', 'Doha']
# ['Emirates', 'Jebel Jais', 'The Gulf', 'Al Hamdeen']
# ['Saudi Arabia', 'Qatar', 'Doha', 'Iran', 'Revolutionary Guard', 'Al-Houthi']
# ['Qatarelix', 'Qatar', 'Doha', 'Qatar_Qatar_Sics']
# ['Iran', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Human Rights', 'Qatar', 'The Hamdeen Organization']
# ['Women's Rights', 'Qatar']
# ['Al-Hamdeen_ terrorist organization', 'Qatar', 'Turkey', 'Iran', 'Doha', 'America', 'Iran', 'Turkey', 'Libya', 'Yemen', 'Somalia']
# ['Hamad_Ben_Khalifa', 'Al-Hamdeen_Terrorist Organization', 'Talal_al_2']
# ['Hamdeen_terrorist Organization', 'Iran', 'Turkey', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Qatar', 'Al-Hamdeen_ terrorist organization', 'Turkey', 'Turkey', 'Libya', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'Al Arab']
# ['Hamdeen_ terrorist organization', 'Saudi Arabia', 'Iran', 'Qatar']
# ['Al Jazeera', 'Qatar', 'Al Arabiya']
# ['Espionage Project', 'Qatar', 'Precaution']
# ['Morocco', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Riyadh']
# ['Hamad_Ben_Jassim', 'Hamad_Bn_Khalifa', 'Azmi_Bishara', 'Meeting _ Fahd_al_the second_twitter']
# ['Tamim', 'Al Jazeera', 'Bahrain', 'Al Qatif', 'Saudi Arabia', 'Qatar', 'London']
# ['Qatar', 'Saudi Arabia', 'The Gulf']
# ['Qatar', 'Meet_ Fahd_al_the second_twitter' ')
# ['Poem', 'urges', 'piety', 'fear', 'God', 'the oppressed']
# male
# ['Qatar_Lags_Promises_Forgiveness`, Qatar, Saudi Arabia, The Gulf]
# ['Abdullah_al_2_alian_alarabiya', 'Sheikh Khalifa bin Mubarak Al-Thani', 'Qatar', 'Doha']
# ['Qatar', 'Corona', 'Hamdeen', 'Doha', 'Tehran']
# ['Qatar', 'Saudi Arabia', 'Arabic']
# ['Kuwait', 'Doha', 'Qatar', 'Saudi Arabia']
# ['Al-Jazeera', 'Doha', 'Rights_ Forgiveness_in_Qatar', 'Qatar', 'Saudi Arabia', 'Al-Arabiya', 'Geneva']
# ['Forgiveness', 'Rights-Forgiveness_in_Qatar', 'Doha', 'Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Al Arabiya']
# ['Hamdeen_ terrorist organization', 'Israel', 'Doha', 'the mullahs' regime, 'Iran', 'Saudi Arabia', 'Tamim']
# ['The Arab Summit Tunisia 2019', 'Tamim', 'Tamim' escapes from the summit ',' The Gulf crisis', 'Qatar', 'Saudi Arabia']
# ['Latifa_musifri', 'Al-Hamdeen_terrorist Organization', 'Qatar']
# ['The_Second_Save_Qatar_Mission_Qatar']
# ['Qatarelix', 'Qatar_financing_terrorism', 'Qatar_something', 'Qatar's bankruptcy', 'Doha_the debunked']
# ['Al Jazeera Channel', 'Qatar', 'Hamad_Ben_Khalifa', 'Meet_ Fahd_al_the second_twitter']
# ['Rulers']
# ['Iran', 'Al Hamdeen_Terrorist Organization', 'Revolutionary Guards', 'Qatar']
# ['Hamdeen_terrorist Organization', 'Gulf', 'Qatar', 'Saudi Arabia']
# ['The Hamdeen Organization', 'Rights Forgiveness' in Qatar', 'Doha', 'Qatar']
# ['Hamdeen_terrorist Organization']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Doha', 'Qatar']
# ['Rights of Forgiveness_in_Qatar', 'Qatar']
# ['Qatar', 'Saudi Arabia', 'Gulf', 'Doha']
# ['The mullahs system']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Al-Hamdeen_Terrorist Organization', 'Al-Rayyan Bank', 'Britain', 'America', 'I am not Qatar']
# ['Tamim', 'Qatar', 'Talal_al-Thani']
# ['Qatar', 'Erdogan', 'Tamim']
# ['Khaled_ Al-Faisal']
# ['Al-Thani', 'Doha', 'Qatar']
# ['Iran', 'Tehran', 'Khamenei', 'America', 'the mullahs' regime,' Qatar ',' Injustice
# ['Hamdeen', 'The Brotherhood', 'Erdogan', 'Tawakkol_kerman']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Saudi Arabia', 'Al-Arabiya']
# ['The Hamdeen Organization']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Doha', 'Gulf', 'Saudi Arabia', 'Egypt', 'Bahrain', 'Emirates', 'Al Jazeera', 'Al Arabiya', 'Al Arab']
# ['Qatar', 'Saudi Arabia', 'Al Jazeera', 'Al Arabiya']
# ['The Tribe of Forgiveness', 'Qatar', 'Latifa_al-Musifri', 'Rights-Forgiveness-In-Qatar', 'The Promise_Qadam_ya_tamim']
# ['Al Jazeera', 'Qatar', 'Hamad_Ben_Khalifa']
# ['Oman', 'Qatar']
# ['The Second', 'The Hamdeen_Terrorist Organization', 'Tamim's dilemma with the second _,' Qatar ']
# ['Salman_Ben_Abdulaziz', “Muhammad_Ben_Salman”, “The National_Saudi_ Today_89”, “The Land of the Two Holy Mosques”]
# ['Al-Hamdeen_ Terrorist Organization', 'Qatar']
# ['Where is Sheikh Talal Al Thani', 'Qatar', 'Saudi Arabia', 'Geneva']
# [“Rights
# ['Corona', 'Turkey', 'Qatar', 'Turkey', 'Iran']
# ['Qatar', 'Tamim']
# ['The regime of the mullahs',' wilayat al-faqih ',' health ',' education ',' economy ',' infrastructure ',' Iran ',' the Gulf ',' the Middle East ',' Qatar ',' honorable ',' Saudi Arabia ',' Emirates', 'Bahrain', 'Egypt']
# ['The Hamdeen Organization', 'Qatar']
# ['Doha', 'Qatar', 'Emirates', 'Arabic']
# ['Qatar', 'Al Jazeera', 'Saudi Arabia', 'Emirates', 'Bahrain', 'The Gulf']
# ['Messenger', 'Abu Bakr', 'Al-Sahib']
# ['Qatar', 'Abd al-Hadi_mani_alhajiri']
# ['Hamdeen', 'Qatar']
# ['Doha, Qatar']
# ['Doha']
# ['Hamdan_Terrorist Organization', 'Britain', 'World Cup 22', 'Hillary Clinton', 'Saud Al-Faisal', 'Abdullah_Ben_Abdulaziz', 'Bahrain', 'Qatar', 'Saudi Arabia']
# ['Hamdeen_terrorist Organization', 'Gulf', 'Qatar', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera']
# ['Forgiveness']
# ['Saudi Arabia', 'Qatar']
# ['Israel', 'Doha', 'Qatar']
# ['Qatar_National Day', 'Qatar', 'Doha', 'Qatarelix', 'National_day_18_December', 'Qatar_Transition Government Meeting']
# ['The Makkah Document', 'Saudi Arabia', 'Al-Hamdeen_Terrorist Organization', 'Qatar']
# ['Qatar', 'Al Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Gulf', 'America', 'Hamad_Ben_Khalifa', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera']
# ['Azmi_Bishara', 'Qatar', 'Tamim', 'Al Hamdeen']
# ['Hamdeen_terrorist Organization', 'Tamim', 'United Nations', 'Libya', 'Rouhani', 'Liar_Like_Abok']
# ['The Hamdeen Organization', 'Al-Wajbah', 'The Land of the Two Holy Mosques']
# ['The Hamdeen Gang']
# ['Saudi Arabia', 'Egypt', 'Bahrain', 'Emirates', 'Al Hamdeen_Terrorist Organization', 'Doha Gang', 'Qatar']
# ['Qatar', 'Al Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya']
# ['Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates',' Egypt ',' Kuwait ',' Yemen ',' Morocco ',' Al Hadath ',' Al Arabiya ',' Al Jazeera ',' Salwa_Marriya Channel ',' The arrest of a Qatari spy in Yemen ',' Injustice of the Qatari endowment for the Qataris', 'Al Hamdeen_steal_the money_ of the Qataris')
# ['Qatar', 'Saudi Arabia', 'Hajj', 'Al-Hamdeen_Terrorist Organization', 'Doha']
# ['Rights-Forgiveness_in_Qatar', 'Qatar', 'Saudi Arabia']
# ['The Saudis-Don_Muhammad', 'The Hamdeen_Terrorist Organization', 'Sharifa', 'Turkey', 'Qatar', 'Al-Arabiya']
# ['Campaign', 'Qatar', 'Qatari', 'Doha', 'Boycott', 'Aviation', 'Airlines', 'Airline', 'Wine']
# ['Sheikh Khalifa bin Mubarak Al Thani']
# ['Hajj', 'Custodian of the Two Holy Mosques', 'Qatar']
# ['Qassem_Soleimani', 'Third World War', 'Qatar']
# ['Eid al-Fitr],' Saudi Arabia ',' Riyadh ',' Jeddah ',' Dammam ']
# ['Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Al Shaer', 'Iran', 'Kuwait']
# ['Bani Hajer Party', 'Qatar_Maid_Mare', 'Qatar']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Riyadh', 'Al Jazeera', 'Al Arabiya']
# ['Al-Hamdeen_ Terrorist Organization', 'The Two Holy Mosques', 'Qatar', 'Al-Jazeera', 'Al-Arabiya', 'Saudi Arabia']
# ['Iraq', 'Lebanon', 'Kingdom of Al-Ahwaz', 'Mullahs' regime, 'Iran']
# ['America', 'Turkey', 'Iran', 'Africa']
# ['Women', 'Men', 'Women', 'Free', 'Men', 'Muslim', 'Muslim women', 'Beautiful', 'Women', 'Qatar']
# ['Qatar', 'News of Al-Weam', 'Ramadan_Barak', 'Ramadan']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt']
# ['Tuna_Mabdina', 'hacking_country_account']
# ['Tamim', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al-Hamdeen_terrorist Organization', 'Gulf']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'Tamim_Bedu_Qatar' surrounded
# ['Al-Hamdeen_ Terrorist Organization', 'Qatar']
# ['world championships', 'qatar']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Kuwait']
# ['Qatar', 'Hamad_Bn_Khalifa', 'Hamad_Bn_jasim', 'The Gulf', 'Iran', 'Turkey', 'Arabia', 'Saudi Arabia', 'Al Jazeera']
# ['Qatar', 'Turkey', 'Iran', 'Meet_Fahd_al_2_twitter'
# ['Al-Hawajir_Sapping_Tzam-Al-Hamdeen', 'Bani Hajer', 'Qatar', 'Saudi Arabia', 'Mebd_hash_abtzt']
# ['Shifaq
# ['Imamoglu', 'Istanbul', 'Al Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera']
# ['the king Salman']
# ['Al-Hamdeen_ Terrorist Organization', 'Qatar', 'Al-Doha Gang']
# ['Trump', 'The mullahs' regime', 'Iran', 'Al-Hamdeen group', 'Qatar', 'Qassem_ Soleimani', 'Tamim']
# ['The Custodian of the Two Holy Mosques', 'Prince_Bandar_Ben_Muhammad_Ben_Abdulrahman']
# ['Hamdeen_terrorist Organization', 'Iran', 'Al Houthi', 'Saudi Arabia', 'Gulf', 'Qatar']
# ['Iran', 'Al Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia', 'Emirates',' Bahrain ',' Egypt ',' Oman ',' Kuwait ',' Gulf ',' Al Arabiya ',' Al Jazeera ',' London ',' Al Arab ']
# ['Tamim_Ben_Ahmed', 'Qatar']
# ['The Ruler', 'The Unjust']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Gulf', 'Al Arabi', 'Island_ Shield', 'North Thunder', 'Al Jazeera', 'Al Arabiya']
# ['Saud_Ben_Jassim_Al_Thani', 'Forgiveness',' Sons of Doha
# ['Tamim', 'Qatar', 'Corona', 'The Gulf']
# ['Corona', 'Tamim', 'Qatar', 'Qatar']
# ['Qatar', 'Saudi Arabia', 'Riyadh', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Al-Thani', 'Doha', 'Oman', 'London']
# ['Hamad_Ben_Khalifa', 'Hamad_Bn_jassim', 'Al Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera']
# ['Qatar_Lines', 'Qatar']
# ['Qatar', 'Saudi Arabia', 'Riyadh', 'Dammam', 'Jeddah', 'Mecca', 'Bahrain', 'Kuwait', 'Oman', 'Emirates',' London ',' Morocco ',' Algeria ',' Iraq ',' Baghdad ',' Al-Mosul ',' Syria ']
# ['Tamim_Talal_Talal_Talal_Talal_Talal_Iprisonment``,' Al Hamdeen_Terrorist Organization ',' Torturing_Children_Second ']
# ['Qatar', 'Doha', 'Saudi Arabia', 'Egypt', 'Bahrain', 'Emirates', 'Al Hamdeen']
# ['Oman', 'Qaboos_Ben_Saeed', 'The death of Sultan Qaboos', 'Qaboos_in_dimmah_of Allah']
# ['Iran', 'honorable', 'Qatar' regime, 'al-Houthi', 'mullahs' regime, 'al-Hamdeen_ terrorist organization']
# ['Qatar', 'Corona']
# ['Hamdeen_terrorist Organization', 'Hajj', 'Qatar']
# ['Interests', 'Defects', 'Qatar', 'Charity', 'Nas']
# ['The injustice of the government of Qatar]
# ['Gaza
# ['Tuesday morning']
# ['Iraq_flashing up']
# ['Al-Hamdeen_ terrorist organization', 'Latifa_ al-Musayfari', 'Qatar', 'Doha', 'Saudi Arabia']
# ['The Hamdeen_terrorist Organization', 'Iran', 'Turkey', 'Saudi Arabia', 'the Jews', 'the land of the Two Holy Mosques', 'The Muslim Qiblah', 'Qatar']
# ['America', 'Qatar', 'Saudi Arabia']
# ['Gulf', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Qatar', 'The Brotherhood']
# ['Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Al Arabiya', 'Al Jazeera']
# ['The Doha Gang', 'Corona', 'The Gulf', 'Al Hamdeen_Terrorist Organization', 'Qatar']
# ['Al Hamdeen', 'The Collapse of the Field Hospital', 'Qatar', 'Saudi Arabia', 'The Gulf']
# ['Qatar', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'Gulf', 'Hamdeen']
# ['Doha', 'FIFA', 'We were not able to do so', 'Al-Qatary Dam', 'Riyadh', 'Hajj']
# ['Persians', 'Hamdeen_ terrorist organization', 'honorable', 'Iran', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Abd al-Hadi_mani_ al-Hajiri', 'Qatar', 'Istanbul']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera']
# ['Tamim', 'Qatar', 'Saudi Arabia', 'Al Arabiya', 'Doha']
# ['Hamdeen_terrorist Organization', 'Saudi Arabia', 'Emirates',' Bahrain ',' Kuwait ',' Yemen ',' Palestine ',' Syria ',' Lebanon ',' Egypt ',' Sudan ',' Libya ',' Tunisia ',' Ethiopia ',' Eritrea ',' Mali ',' India ',' Sri Lanka ',' America ',' Britain ',' Italy ',' France ',' Somalia ']]
# [“Rights
# ['Hamdeen_terrorist Organization', 'Saudi Arabia', 'Gulf', 'Qatar']
# ['Qatar', 'Bahrain', 'Al Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Al Arabiya']
# ['Sudan', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Oman', 'Kuwait', 'Arabia', 'Al Jazeera']
# ['Iran', 'Gulf', 'Doha', 'Al-Hamdeen_terrorist Organization', 'Qatar', 'Azmi_Bishara', 'Saudi Arabia']
# ['Qatar_']
# ['Campaign of arrests of the Occupied Sisters of Tunisia']
# ['Qatar', 'a ransom_billion_dollars']
# ['Abdullah_al_2_AliArabia', 'Qatar']
# ['Haitham_Ben_Tariq_Al_Said' ',' Oman ']
# ['Qatar', 'Saudi Arabia', 'Al Hamdeen_Terrorist Organization', 'Doha', 'Doha Gang', 'Al Arabiya']
# ['Qatar', 'Doha', 'Corona']
# ['Qatar', 'Al-Hamdeen_ terrorist organization', 'Iran', 'Turkey', 'Doha', 'Qatar', 'Iraq']
# ['Qatar', 'Doha', 'Saudi Arabia']
# ['Tamim', 'Qatar']
# ['The Arab Gulf Summit in Makkah', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Gulf', 'Arab', 'Al Jazeera']
# ['Hamdeen_ terrorist organization', 'Al-Ghufran tribe', 'Doha gang']
# ['The country', 'the people']
# ['The Terrorist Attack', 'Saudi Arabia', 'Iran', 'Al Houthi', 'The Hamdanid_Terrorist Organization', 'Saudi Arabia', 'The Gulf', 'Qatar']
# ['Iran', 'Al Hamdeen_Terrorist Organization', 'Hezbollah', 'Lebanon', 'Qatar', 'Doha']
# ['Iran', 'Saudi Arabia', 'Iraq', 'the mullahs' regime', 'Qatar']
# ['Qatar', 'Hamdeen Gang', 'Saudi Arabia', 'Emirates', 'Erdogan', 'We are all_Ayid Al-Qarni']
# ['Watch', 'China', 'Uighurs']
# ['Qatar crisis', 'Saudi Arabia']
# ['Corona', 'Qatar']
# ['Glory be to goodness and goodness']
# ['Qatar', 'Saudi Arabia']
# ['The Hamdeen Organization', 'The Hamdeen Gang']
# ['Qatar', 'Iraq']
# ['The Sword_Ajrab']
# ['Saudi Arabia', 'The Gulf']
# ['Tamim', 'Iran', 'The World Cup', 'Azmi Bishara', 'Qatar', 'The Gulf']
# ['Latifa_Musifri', 'Al Hamdeen_Terrorist Organization', 'Qatar', 'Doha']
# ['Rights_ Forgiveness_in_Qatar', 'Qatar', 'Saudi Arabia', 'Emirates',' Jordan ',' Dubai ',' Bahrain ',' Kuwait ',' London ',' Egypt ',' Riyadh ',' Syria ',' Palestine']
# ['Al Arab', 'Al Arabiya', 'Al Jazeera', 'Morocco', 'Libya']
# ['Somalia', 'Doha', 'Africa', 'Mogadishu', 'Al-Hamdeen_ terrorist organization']
# ['Muhammad_Ben_Khalifa_l_2' ', `` Ahmed_Ben_Khalifa_l_2' ', `` Al Hamdeen_Terrorist Organization' ', `` Qatar' ']
# ['Trump', 'Qatar', 'The Doha Gang']
# ['Qatar', 'Corona', 'Gulf', 'Tamim', 'Doha', 'Doha']
# ['Muhammad_kahla_ prisoner_rai']
# ['Qatar', 'Al-Hamdeen Organization', 'Qatar']
# ['Qatar', 'Latifa_almsifari', 'Saudi Arabia']
# ['Iran', 'Al-Hamdeen_ terrorist organization', 'Doha', 'Tehran', 'Makkah summit', 'Al-Houthi', 'Qatar']
# ['Saudi Arabia', 'Muhammad_Ben_Salman_in_the Twentieth Summit', 'Qatar', 'Riyadh', 'Arabic']
# ['Qatar', 'Qatar_bids_hajj_of its citizens', 'Doha', 'Saudi Arabia']
# ['Qatar', 'The Gulf', 'Hamad_Ben_Khalifa', 'Saudi Arabia', 'Al Arabiya']
# ['Azmi_Bishara']
# ['Turkey', 'Al-Hamdeen_ terrorist organization', 'Tamim', 'Erdogan']
# ['Israel', 'Netanyahu', 'the Hamdeen_terrorist Organization', 'Palestine', 'Doha', 'The Arab Nation', 'The Hamdanid Organization', 'Qatar', 'The Gulf']
# ['Hajj', 'Qatar', 'Saudi Arabia', 'Internationalization of the Two Holy Mosques']
# ['Al-Hamdeen_terrorist Organization', 'Qatar', 'Saudi Arabia', 'Gulf', 'Al-Hamdeen Organization', 'Azmi_Bishara', 'Al-Arabiya', 'Gulf']
# ['The Hamdeen_terrorist Organization', 'Israel', 'Gaddafi', 'Saudi Arabia', 'Qatar', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'The Gulf']
# ['Qatar', 'Emirates', 'Kuwait', 'Bahrain', 'Oman', 'Egypt', 'The Blessed Eid']
# [“Qatar”, “Al-Hamdeen_ terrorist organization”, “Al-Muhannadi”, “Tamim”, “Indonesia”, “Doha-Gang”, “Saudi Arabia”]
# ['Hamdeen_terrorist Organization', 'Qatar', 'Saudi Arabia', 'Emirates', 'Al-Jafourah field', 'Haql_ Mahani']
# ['Qatar', 'National_Service_Qatar', 'Emirates']
# ['The Hamdeen_Terrorist Organization', 'Hamad_Bn_Khalifa', 'Qatar', 'Iran', 'The Gulf']
# ['Hamdeen_ Organization', 'Qatar', 'Saudi Arabia', 'Egypt']
# ['Qatar', 'Al Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt']
# ['Qatar', 'Eid al-Fitr')
# [“Rights
# ['Iran', 'Lebanon', 'Iraq', 'Syria', 'Yemen', 'Al-Houthi', 'Al-Hamdeen_Terrorist Organization', 'Hezbollah', 'Qatar']
# ['Tamim', 'Qatar', 'Doha']
# ['Qatar', 'Saudi Arabia', 'Khashoggi', 'Al Jazeera']
# ['Qatar', 'Al Hamdeen_Terrorist Organization', 'Al Houthi', 'Saudi Arabia', 'Al Arabiya']
# ['Hamad_Bn_Jassim', 'Qatar', 'Mullahs' regime, 'Al Arabiya', 'Al Jazeera', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt']
# ['New_Qatar', 'Hamdeen']
# ['Freedom_All_second', 'The case of the second']
# ['Qatar', 'The Second', 'Turkey', 'Erdogan']
# ]
# ['The Hamdeen_ terrorist organization', 'the mullahs' regime, 'Iran', 'Al-Arabi al-Jadid', 'Doha-gang', 'Palestine', 'Persians', 'Qatar', 'Saudi Arabia']
# ['Qatar', 'Doha', 'World Cup 22', 'Corona']
# ['Hamdeen_terrorist Organization', 'Germany', 'Qatar', 'Doha', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Arabs', 'London']
# ['Gulf']
# ['Human Rights', 'Qatar', 'Torture of Sheikh Fahd']
# ['Tamim', 'America', 'California']
# ['Hamdeen', 'Tamim', 'Qatar']
# ['Iran']
# ['Infographic', 'Doha', 'Qatar', 'Qatarelix', 'Tamim Drains Qatar', 'Tamim
# ['Forgiveness', 'Ali_Mari']
# ['Oppression']
# ['Khalifa_Ben_Marak_Al_Thani', 'Doha', 'Al Hamdeen', 'Doha']
# ['Human Rights', 'Torture of Sheikh Fahd']
# ['Rights of Forgiveness_in_Qatar']
# ['Torture of Sheikh Fahad', 'Qatar']
# ['Qatar', 'Qatar Central Bank', 'Doha']
# ['Isolated Doha', 'Standard_and_borz', 'Qatar']
# ['Abdullah_Ben_Fahd_Al_Thani', 'Al Hamdeen', 'The Muqata', 'Qatar']
# ['Iran', 'Trump', 'Sky_News']
# ['Erdogan', 'Sky_News']
# ['Hamdeen', 'The injustice of the government of Qatar', 'Qatar']
# ['Rulers', 'Presidents', 'The President', 'Injustice', 'Qatar', 'Doha', 'Egypt', 'Cairo']
# ['Al-Kahleh', 'Qatar', 'Doha']
# ['The Leader', 'The Leaders', 'Expressing', 'His Wisdom', 'The Man', 'The Men']
# ['Tehran', 'Britain', 'Mastaba']
# ['Forgiveness-in-the-Hague', 'Rights-Forgiveness-in-Qatar']
# ['Qatar', 'Iran', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Qatar', 'Al-Rabee', 'Countries', 'Arabic']
# ['Al-Madinah Al-Munawrah', 'Bahrain']
# ['Iran', 'Tehran']
# ['Obama', 'Iran', 'Turkey', 'China']
# ['Qatar', 'Trojan horse', 'Gulf', 'Yemen', 'Houthi', 'Qatar', 'Saudi Arabia', 'Emirates',' Bahrain ',' Egypt ',' Oman ',' Kuwait ',' Arabic ',' Al Jazeera ',' Arabs', 'Arabistan', 'Ahwaz']
# ['Hamad_Bn_Khalifa', 'The Hamden_Terrorist Organization']
# ['Qatar', 'Saudi Arabia', 'Khashoggi']
# ['Al-Hamdeen_ terrorist organization', 'al-Hamdeen_ terrorist organization', 'Turkey', 'Sharifa']
# ['Tamim', 'The Gulf']
# ['Tamim']
# ['Adel_Jubeir', 'America']
# ['Qatar', 'Azmi_Bishara', 'Al Houthi', 'Al Hazm Storm', 'Doha', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt']
# ['Khalifa_Ben_Soud', 'Al Gharafa', 'Al-Thani', 'Al-Doha Gang']
# ['The Arabian Gulf']
# ['Hamad_Ben_Khalifa']
# ['Hamdeen_ Organization', 'Qatar', 'Al Jazeera', 'Al Arabiya']
# ['Revolutionary Guards']
# ['Qatar', 'Libya', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Qatar-First Bank', 'Qatar', 'Al-Hamdeen_Terrorist Organization']
# ['Al-Ahwaz', 'Iran', 'Al-Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Arabistan', 'London']
# ['Jubail', 'Revolutionary Guard', 'Saudi Arabia']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'London']
# ['I take care', 'Al-Jawwal', 'Qatar']
# ['Saudi Arabia', 'Kuwait', 'Emirates', 'Bahrain', 'Gulf Cooperation Council', 'Qatar', 'Egypt']
# ['Decisive Storm']
# ['Doha', 'The Persians']
# ['Qatar', 'Qatar']
# ['Sherifa', 'Ras_tannurah', 'Mecca_Makramara']
# ['Doha', 'Qatar', 'Qatar']
# ['Al-Hamdeen_ Terrorist Organization', 'Rights_ Forgiveness_in_Qatar']
# ['Injustice
# ['Qatar', 'Saudi Arabia', 'Hamad_Bn_Khalifa', 'Hamad_Ben_jasim', 'The Gulf', 'Iran']
# ['Iran', 'America', 'the mullahs' regime]
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'Riyadh', 'Rights-Forgiveness_In_Qatar', 'Doha']
# ['Qatar_pays_the demonstrators_300_pounds', 'Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt']
# ['Citizen', 'Minister', 'Ruler', 'Rulers', 'Responsible', 'Arab', 'President', 'Countries']
# ['Qatar', 'Al-Hamdeen']
# ['Al-Hamdeen_ terrorist organization', 'Corona', 'Qatar']
# ['Tamim', 'Iran', 'Qatar', 'The Gulf', 'The Mullahs' System]
# ['Hamad_Bn_Khalifa', 'The Unemployed_Qatari Group', 'Tamim', 'Azmi_Bishara', 'Qatar']
# ['Sudan', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'The Gulf']
# ['We direct our appeal', 'Imam of the Muslims', 'The Custodian of the Two Holy Mosques', 'King Salman_Ben_Abdulaziz_Al_Saud', 'To save Qatar_from the Hamdeen organization', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Arabia']
# ['Hamdeen', 'Qatar', 'America', 'Trump']
# ['Al-Hamdeen_ terrorist organization', 'Qatar', 'Doha']
# ['Tehran', 'Ankara', 'Qatar', 'Fahd_al_the second_twitter' meeting
# ['Qatar', 'Israel', 'Israel', 'America', 'Libya', 'Somalia']
# ['Qatar', 'Gulf', 'Saudi Arabia']
# ['Tamim', 'Qatar', 'Al-Udeid Base']
# ['The King', 'Bahrain']
# ['Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Oman', 'Kuwait', 'Riyadh', 'Arabia', 'Al Jazeera']
# ['Doha', 'Al-Thani', 'Qatar', 'Al-Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Al-Arabiya', 'Al-Jazeera']
# ['The explosion of my oil tankers in the Sea of Oman', 'Iran', 'Saudi Arabia', 'Emirates', 'the mullahs' regime, 'Qatar']
# ['The Saudis-Don_Muhammad', 'We are all_don_Mohammed', 'The Land of the Two Holy Mosques', 'Mecca', 'Medina']
# ['Saudi Arabia', 'Qatar', 'Tweet_ about your love for Saudi Arabia']
# ['Qatar', 'Yemen', 'Al-Hamdeen_Terrorist Organization', 'Al-Jazeera', 'Doha', 'Contradictions of the Qatari regime']
# ['Talal_al_second', 'Humanitarian A Heartbreaking Report', 'The Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera']
# ['Hamad_Bn_Khalifa', 'The Qatari_ Shura Council', 'Qatar', 'Al Hamdeen_Terrorist Organization', 'Turkey', 'Iran', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera', 'London']
# ['King_Abdulaziz_Camel_4 Festival']
# ['Qatar', 'Iran', 'Hezbollah', 'Tamim', 'the Hamdanid_terrorist Organization', 'Lebanon', 'Saudi Arabia']
# ['Kuwait', 'Al Jazeera', 'Qatar']
# ['The Hamden_Terrorist Organization', 'The Arab Gulf Summit' in Makkah, 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'The Gulf']
# ['First Bank of Qatar']
# ['God', 'Al Hakim', 'Authority', 'Virtues', 'Omar', 'Egypt', 'Pray_on the Prophet', 'Al Jazeera', 'Beautification', 'America', 'Ramadan']
# ['Al-Hawajir
# ['Hamdeen_terrorist Organization', 'Qatar', 'Saudi Arabia', 'Al Jazeera', 'Al Arabiya', 'Doha', 'The Gulf']
# ['Saudi Arabia', 'Gulf', 'Egypt', 'Hamdeen_terrorist Organization', 'Azmi_Bishara', 'Qatar', 'Bahrain', 'Emirates']
# ['Qatar_Nationalday', 'Qatar', 'Doha', 'Qatarelix', 'National_day_18_December']
# ['Geneva', 'Talal-al-Thani', 'Doha', 'Qatar', 'Torture of children-al-Thani']
# ['The regime of the mullahs', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'London']
# ['Doha', 'Al-Hamdeen_Terrorist Organization', 'Qatar']
# ['Iraq', 'America', 'Saudi Arabia', 'Qatar', 'Baghdad']
# ['Hamdeen_terrorist Organization', 'Saudi Arabia', 'Qatar', 'Emirates', 'Bahrain', 'Egypt']
# ['Latifah Al-Musayfari', 'Organization of Al-Hamdan']
# ['Egypt', 'Al-Hamdeen_Terrorist Organization', 'Gulf', 'Doha', 'Qatar', 'Saudi Arabia', 'Al-Arabiya']
# ['Qatar', 'Kuwait', 'Bahrain', 'Emirates',' Saudi Arabia ',' Oman ',' Jordan ',' Iraq ',' London ',' Tunisia ',' Poets', 'Ramadan', ' Poetry ',' verses']
# ['Hamdeen_ terrorist organization', 'Egypt', 'Doha', 'Al Jazeera Channel', 'Qatar', 'London']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Doha', 'Israel']
# ['Tamim', 'Rights_ Forgiveness_in_Qatar']
# ['Hamdeen_ terrorist organization', 'Iran', 'Turkey', 'the Two Holy Mosques', 'Arab Gulf', 'Qatar', 'Saudi Arabia']
# ['Qatar', 'Al Hamdeen_Terrorist Organization', 'London', 'Saudi Arabia']
# ['Hamdeen_terrorist Organization', 'Saudi Arabia', 'Qatar', 'Gulf', 'Doha']
# ['New_Qatar']
# ['America', 'Britain', 'The Emirates', 'Malaysia', 'The Netherlands', 'Singapore', 'Iran', 'The Hamidin_Terrorist Organization', 'The Mullahs' Regime, 'Qatar', 'Al Jazeera', 'Al Arabiya']
# ['Arabs', 'Syria', 'Damascus airport', 'surgeries', 'Algeria', 'Libya', 'Morocco', 'Tunisia', 'torture', 'poetry', 'poetry' and 'khawatir']
# ['Hamdeen_ terrorist organization', 'Qatar', 'Saudi Arabia', 'Gulf', 'Doha']
# ['Qatar', 'Qatar_Petroleum', 'Saudi Arabia']
# ['Al-Hamdeen_ Terrorist Organization', 'Qatar', 'Barclays', 'FIFA']
# ['Al Hamdeen', 'The Gulf', 'Al Arabiya', 'Qatar']
# ['The Hamdeen Organization', 'The Gulf', 'Qatar', 'Saudi Arabia', 'Bahrain', 'The Emirates', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Al Shaer', 'Iran', 'Kuwait']
# ['Explosion of two oil tankers in the Sea of Oman', 'Abha airport', 'Iran', 'European Union', 'Abha', 'Qatar']
# ['People of Qatar is in danger']
# ['Hamdeen_ terrorist organization', 'Tamim', 'Hamdeen', 'Tamim']
# ['Al-Thani', 'Qatar', 'Saudi Arabia', 'Al-Jazeera', 'Al-Arabiya']
# ['Al-Hamdeen_ terrorist organization', 'Qatar', 'Europe']
# ['Talal_al_2', 'Qatar', 'Al-Hamdeen']
# ['Al-Hamdeen_terrorist Organization', 'Qatar', 'Tamim_Ben_Hamed']
# ['Erdogan', 'Tamim', 'Turkey', 'Iran']
# ['The Transitional Government Meeting of Qatar']
# ['The mullahs' regime', 'Qatar', 'Saudi Arabia'
# ['Kuwait', 'Qatar', 'Saudi Arabia', 'Riyadh', 'Honorable_Al-Thani', 'Statements_al_second_Arabic']
# ['Emirates', 'Qatar', 'Saudi Arabia', 'Bahrain', 'Egypt']
# ['Al Jazeera', 'Mosul_Now', 'Al Arabiya']
# ['Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Qatar']
# ['Qatar', 'Al-Hamdeen_Terrorist Organization']
# ['Qatar', 'Emirates', 'Saudi Arabia', 'Kuwait', 'Bahrain', 'Dubai', 'London', 'Human Rights', 'Justice', 'Iraq', 'France']
# ['Gulf', 'Saudi Arabia', 'Al-Hamdeen_Terrorist Organization', 'Country of the Two Holy Mosques']
# ['Muhammad_Ben_Khalifa_al_Thani', 'Ahmad_Ben_Khalifeh_al_th2' ')
# ['Vote
# ['The Second', 'The Gulf', 'Qatar']
# ['Tamim', 'Cup_Alal_22', 'Qatar']
# ['National_Service_in_Qatar', 'Al-Hamdeen_Terrorist Organization', 'Turkey', 'Iran']
# ['Doha', 'Forgiveness', 'Qatar', 'Human Rights']
# ['Injustice', 'Qatar']
# ['Al-Thani', 'Tamim', 'America', 'Qatar', 'Tamim's dilemma-with-the-second', 'Saudi Arabia']
# ['Hamdeen_ Organization', 'Qatar', 'Saudi Arabia', 'Al Jazeera', 'Al Arabiya']
# ['Caliph_Ben_Ahmed', 'Tamim']
# ['Hamdeen_terrorist Organization', 'Sharifa', 'Doha', 'Qatar']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Kuwait', 'Al Jazeera', 'Mosul', 'Al Arabiya']
# ['Janadriyah Festival_32']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Doha']
# ['Iran', 'Qatar', 'the Hamdanid terrorist organization', 'the mullahs' regime, 'the Doha gang', 'Al Jazeera', 'Saudi Arabia', 'Al Arabiya']
# ['Khamenei', 'Revolutionary Guards',' Zarif ',' Iran ',' Zarif ',' The Iranian regime ',' Injustice ',' Qatar ',' Saudi Arabia ',' The Emirates', 'Bahrain', 'Egypt', ' Arabic ',' Al Jazeera ',' London ']
# ['Trump', 'American Senate', 'Hamdeen', 'Iran', 'Gulf', 'Turkey', 'Qatar', 'Doha Gang']
# ['Qatar', 'Yemen', 'the Hamdanid_terrorist Organization', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera', 'Emirates', 'Bahrain', 'Egypt', 'Gulf', 'Oman', 'Kuwait']
# ['Al-Hamdeen_ Terrorist Organization', 'Qatar', 'Doha', 'Doha Gang', 'Al-Jazeera']
# [“Tamim
# ['Doha', 'Saudi Arabia', 'Egypt', 'Egypt']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Azmi']
# ['Tamim', 'Qatar', 'Italy', 'Somalia', 'Al-Hamdeen Organization', 'Somalia', 'Mogadishu bombings']
# ['Hamdeen_ terrorist organization', 'honorable', 'America', 'Iran', 'Saudi Arabia', 'Emirates',' Bahrain ',' Egypt ',' Syria ',' Qatar ',' Jordan ',' Libya ',' Arabic']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'Riyadh']
# ['Doha', 'The Martyr_Fahad_Buhendi', 'Qatar']
# ['Tamim', 'Lusail Yacht', 'Doha', 'Qatar']
# ['The mullahs' regime, 'Iran', 'Doha', 'Lebanon', 'Iraq', 'Yemen', 'Sharifa', 'Qatar', 'Saudi Arabia', 'London']
# ['Al-Hamdeen_Terrorist Organization', 'Forum of Renaissance', 'Academy of Change', 'Arab Foundation for Democracy', 'Doha', 'Qatar']
# ['Hamdeen_terrorist Organization', 'Iran', 'Question_for the Hamdeen Organization', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'Gulf', 'Tamim_faring_protection staff']
# ['Hamdeen_ terrorist organization', 'honorable', 'Iran', 'al-Hamdeen_ terrorist organization', 'Tunisia', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt']
# ['The Men', 'Hmm', 'The Mountains', 'Qatar', 'Doha']
# ['Marines', 'Sharifa', 'Hamdeen', 'Qatar']
# ['Hamdeen', 'Qatar', 'Hamdeen', 'Al-Thani', 'Saudi Arabia', 'Red-line']
# ['Qatar', 'Al-Hamdeen_Terrorist Organization', 'Hajj', 'Makkah']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Iran', 'Houthi', 'Gulf', 'Saudi Arabia']
# ['Caricature 24']
# ['Lebanon', 'Iraq', 'Iran', 'Yemen', 'Qatar']
# ['Qatar', 'Hamdeen', 'Corona']
# ['Human Rights', 'Al Hamdeen_Terrorist Organization', 'The Forgiveness Tribe', 'Qatar']
# ['Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Iran', 'America', 'Qatar', 'Tamim', 'Hamdeen']
# [“Rights
# ['Arabistan', 'Khazal', 'Muhammarah', 'Tehran', 'Reza_Pahlavi', 'Qatar', 'Saudi Arabia', 'Emirates',' Bahrain ',' Egypt ',' Oman ',' Kuwait ',' Arabic ',' Ahwaz ',' Libya ',' Morocco ']
# ['Stop_the South Protected Area Project', 'Qatar', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Syria', 'Mosul', 'Iraq', 'Kuwait', 'Bahrain', 'B', 'S']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Baghdad']
# ['The Hamdeen Organization', 'Latifa Al-Musifri', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt']
# ['Human rights in Qatar', 'World Cup 22', 'Qatar']
# ['Al-Hamdeen_ Terrorist Organization', 'World_Games_Always_ Doha 2019', 'America', 'Britain', 'Europe', 'Qatar']
# ['Al-Hamdeen_ Terrorist Organization', 'Qatar', 'The Gulf']
# ['Iran', 'honorable', 'the mullahs' regime]]
# ['Tamim
# ['Iran', 'the mullahs' regime', 'Qatar', 'Saudi Arabia', 'Al Arabiya', 'The Gulf']
# ['Qatar', 'Doha', 'the Hamdeen_terrorist Organization', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Qatar', 'Iran', 'Qatar_bids_ its citizens_ from_ the Hajj', 'Qatar_bids_ the pilgrimage of its citizens']
# ['Iraq', 'Sharifa', 'Iran', 'Tehran', 'Mecca', 'Qatar']
# ['Qatar', 'Schools', 'Doha']
# ['Qatar', 'his wisdom']
# ['Qatar', 'Al-Hamdeen_ terrorist organization', 'Saudi Arabia', 'Gulf', 'Al-Arabiya', 'Al-Thani', 'Iran']
# ['Hamdeen', 'Herd immunity', 'Corona', 'World Cup 22', 'Qatar', 'Tamim']
# ['Iran', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'The Gulf']
# ['Rights_Gran_In_Qatar', 'Qatar']
# ['The People of Qatar
# ['Barakat']
# ['The Tribe of Forgiveness', 'Watch_sky']
# ['Hamdeen_terrorist Organization', 'Gulf']
# ['Okaz', 'Qatar', 'Hamdeen']
# ['Al-Hamdeen Organization', 'Okaz', 'Qatar', 'To be_first']
# ['Sheikh Khalifa bin Mubarak Al Thani', 'The Middle East']
# ['Saudi National Day']
# ['Doha', 'Qatar', 'Iran', 'Al-Qaeda_Al-Udeid', 'Yemen']
# ['Khashoggi', 'Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Al Jazeera', 'Al Arabiya', 'Riyadh', 'We are all trustworthy in_Muhammad_Ben_Salman']
# ['Hamdeen_ terrorist organization', 'America', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Mauritania', 'Egypt', 'Yemen', 'Chad', 'Qatar']
# ['Hamad_Ben_Khalifa', 'Saudi Arabia', 'Meet_ Fahd_al_the second_twitter']
# ['Hamdeen Gang', 'Houthi', 'Riyadh', 'Gulf', 'Qatar', 'Saudi Arabia']
# ['Hamad_Ben_Jassim', 'Al Hamdeen_Terrorist Organization', 'Gaddafi', 'Saudi Arabia', 'Al Mohannadi', 'Mogadishu', 'Somalia', 'Qatar', 'London']
# ['The second_saving Qatar' meeting, 'Qatar', 'Doha']
# ['Al-Udeid base', 'Qatar', 'Turkey', 'Iran', 'Revolutionary Guards']
# ['Qatar', 'Doha', 'United Nations']
# ['Hypocrisy', 'Interest', 'Throwing You', 'Interests']
# ['Latifa_musifri', 'Doha', 'Saudi Arabia', 'Tamim_Support_Idash_Uyghur', 'Al Arabiya', 'Al Jazeera']
# ['The mullahs' regime, 'Doha', 'Iran', 'honorable', 'the Hamdanid_ terrorist organization', 'Qatar', 'London']
# ['Sudan_refuses_welcome_ Qatar', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['King Abdulaziz_Camel Festival']
# ['Qatar', 'Barcelona_Real_Madrid']
# ['Iran', 'Arab Gulf', 'Tamim', 'Tamm_Aleb']
# ['Qatar', 'Saudi Arabia', 'Kuwait']
# ['Khashoggi case', 'Saudi Arabia', 'Doha Gang']
# ['What Iran brought to the region', 'Iran', 'the Hamdanid terrorist organization', 'Qatar', 'Al Arabiya', 'Al Jazeera', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt']
# ['Hamdeen_ terrorist organization', 'Turkey', 'Libya', 'Doha', 'Tamim', 'Syria']
# ['Blatter', 'FIFA', 'World Cup 22', 'Sarkozy', 'America', 'Doha', 'Qatar']
# ['Hamdeen_ terrorist organization', 'The Hague', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'London', 'Rights_ Forgiveness_in_Qatar']
# ['Security services', 'Rulers', 'Muslim_people']
# ['The Custodian of the Two Holy Mosques', 'Salman bin Abdulaziz', 'Muhammad_Ben_Salman', 'Eid_Al-Adha_ the Blessed', 'Mona', 'Hajj', 'Arif him']
# ['Saudi Arabia', 'The Land of the Two Holy Mosques']
# ['Tamim_Ben_Ahmed', 'Turkey', 'Iran', 'Qatar', 'Saudi Arabia']
# ['Qatar', 'Emirates']
# ['Tehran', 'Ukraine', 'Revolutionary Guards', 'Doha', 'Qatar']
# ['Britain', 'Al-Rayyan Bank', 'Qatar', 'Doha']
# ['Qatar', 'Rights-Forgiveness_in_Qatar']
# ['Tamim', 'Tamim', 'America', 'The World Cup 22']
# ['Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Dhahran Summit']
# ['Al-Hamdeen_ terrorist organization', 'Latifa_ al-Musayfari', 'Qatar']
# ['America', 'Iran', 'Saudi Arabia', 'America', 'Britain', 'Revolutionary Guard', 'Al-Hamdeen_Terrorist Organization', 'Qatar']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Egypt', 'Riyadh']
# ['The Hamdeen_Terrorist Organization', 'Hamad_Bn_Khalifa', 'Hamad_Ben_jasim', 'Facts_In evidence', 'Qatar', 'Saudi Arabia']
# ['Qatar Stock Exchange Collapse', 'Qatar']
# ['Boycott', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Gulf', 'Al Arabiya', 'Al Jazeera', 'Al Hamdeen_Terrorist Organization']
# ['Qatar', 'Saudi Arabia', 'The Emirates']
# ['Qatar', 'Israel', 'Palestine', 'London']
# ['Okaz', 'Friday', 'Bloomberg', 'Tax', 'Banks', 'Water']
# ['Qatar', 'Hamdeen', 'Echo of the Country', 'The Country']
# ['Tamim', 'Yemen', 'Syria', 'Libya', 'Saudi Arabia', 'Gulf', 'Damage Summit']
# ['Fahad_Al_Thani', 'Saudi Arabia', 'Qatar', 'Qahtan tribes']
# ['Al Jazeera Channel', 'Egypt', 'Al Hamdeen_Terrorist Organization', 'Qatar', 'Saudi Arabia']
# ['Qatar', 'Ramadan']
# ['Al-Hamdeen_ terrorist organization', 'Libya', 'Gulf', 'Qatar', 'Turkey']
# ['Makkah']
# ['Qatar_nationalday', 'Qatar', 'Doha', 'Qatarelix']
# ['Hamdeen_ terrorist organization', 'Aramco attacks', 'Erdogan', 'Rouhani', 'United Nations', 'Qatar']
# ['America', 'Iran', 'the mullahs' regime, 'Saudi Arabia', 'Gulf', 'Qatar', 'Oman', 'Houthi', 'Saudi Arabia', 'Al-Arabiya', 'Al-Jazeera']
# ['The Turkish-Qatari-rule']
# ['Iran', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt']
# ['Qatar', 'Fahd_Ben_Allah_Al_Thani', 'The injustice of the government of Qatar to where', 'Saudi Arabia']
# ['Salman_Ben_Abdulaziz', 'Muhammad_Ben_Salman', 'Ramadan']
# ['Meeting of Kabyle Qahtan', 'Qatar']
# ['Day of Arafah', 'Qatar', 'Saudi Arabia', 'Hajj']
# ['The mullahs' regime, 'Iran', 'Tamim', 'Rouhani', 'Qatar', 'Saudi Arabia']
# ['Arab Spring', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera']
# ['Al-Hamdeen_Terrorist Organization', 'Qatar', 'World Cup 22', 'Saudi Arabia', 'Al Arabiya', 'Al Jazeera', 'Doha']
# ['Al-Hamdeen_ Terrorist Organization', 'Britain', 'Qatar']
# ['Iran']
# ['Al Hamdeen', 'Tamim', 'Qatar', 'Saudi Arabia', 'The Gulf']
# ['America', 'the mullahs' regime', 'Qatar', 'Saudi Arabia', 'Emirates',' Bahrain ',' Egypt ',' Al Jazeera ',' Al Arabiya ']
# ['Jassim_Ben_Muhammad_Ben_Thani' ', `` The founder of the State of Qatar' ', `` Qatar' ', `` Qatar_thanks_shaayir_ Allah' ')
# ['Arab Spring', 'Qatar']
# ['Tamim', 'America', 'Trump', 'Qatar']
# ['Yemen', 'Riyadh Agreement', 'Al-Houthi', 'Saudi Arabia', 'The Gulf']
# ['Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Qatar', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'London']
# ['Qatar', 'Al-Houthi', 'Gulf', 'Iran', 'Israel', 'Doha']
# ['Doha', 'Hamdeen', 'Tamim', 'Iran', 'Turkey', 'The Satan Party', 'Germany']
# ['Korea', 'America', 'Al-Hamdeen_ terrorist organization', 'Qatar']
# ['Al Hamdeen_Terrorist Organization', 'Al Houthi', 'Saudi Arabia']
# ['Injustice', 'Qatar', 'Saudi Arabia']
# ['Qatar', 'Iran', 'Meet_ Fahd_al_the second_twitter']
# ['Qatar', 'Emirates', 'Saudi Arabia']
# ['The Hamdeen Organization', 'Qatar', 'Tamim', 'Iran', 'Turkey', 'Al-Houthi']
# ['Qatar', 'A tragedy of children_second']
# ['Corona', 'Iran', 'Sharifa', 'Tamim', 'Jordan', 'Qatar']
# ['Question_ to organize_ Al Hamdeen', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Oman', 'Kuwait', 'Morocco', 'Algeria', 'Libya', 'Tunisia', 'Countries', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Qatar']
# ['Qatar', 'Curfew']
# ['Emirates', 'Hazza_Almansouri', 'Ambition_Zayed']
# ['Saudi Arabia', 'Hamdeen_ terrorist organization', 'Turkey', 'Deal of the Century', 'Doha Gang', 'Qatar']
# ['The mullahs' regime, 'Qatar', 'Khamenei', 'Al-Hamdeen_terrorist Organization', 'Doha', 'Iran_Treatens_Without Qatar', 'Saudi Arabia']
# ['Qatar', 'Alliance_support_legitimacy', 'Yemen', 'Great Saudi Arabia', 'Iran', 'Al-Hamdeen_ terrorist organization', 'Al-Arabiya']
# ['Statements of_A_2_Arabic', 'Qatar', 'Rights_ Forgiveness_in_Qatar', 'Geneva']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Kuwait', 'Al Jazeera', 'Mosul_Now', 'Al Arabiya', 'London']
# ['Tuna_Mabdina']
# ['Revolution', 'Iranian', 'Film', 'White House', 'President', 'American', 'Trump', 'Qassem', 'Soleimani']
# ['Qatar', 'Al-Hamdeen_Terrorist Organization', 'Doha']
# ['Saudi Arabia', 'Falcons and Saudi Hunting Exhibition', 'The Gulf']
# ['Facts_in_Minutes',' The Three Summits
# ['Pilgrimage']
# ['Trump', 'Al-Udeid Base']
# ['Meet_Second_InArabia`]
# ['Iran', 'Sharifa', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Arab']
# ['The Hamdeen_Terrorist Organization', 'Hamad_Bn_Khalifa', 'The Gulf', 'Tamim']
# ['Hamad_Ben_Khalifa', 'Orphan_Lajdee', 'The Qatari System']
# ['Qatar', 'Orphan_majdie']
# ['Arabia', 'Qatar', 'Tamim', 'America', 'Sudan']
# ['Great Saudi Arabia', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera', 'The Gulf']
# ['Qatar', 'Tamim's laugh', 'Trump', 'America', 'Al-Hamdeen_ terrorist organization']
# ['Qatar's withdrawal from the summit of Mecca', 'the mullahs' regime, 'Iran', 'Al-Hamdeen_ terrorist organization', 'Qatar']
# ['Hamdeen_ Organization', 'Qatar', 'Saudi Arabia']
# ['Gulf', 'Al-Hamdeen_Terrorist Organization', 'Qatar']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Palestine', 'Al Arabiya']
# ['Iran', 'the mullahs' regime', 'the Hamdeen_terrorist organization', 'Saudi Arabia', 'the Gulf', 'Qatar']
# ['Eid al-Fitr']
# ['Erdogan', 'Qatar', 'Tamim', 'Al Hamdeen_Terrorist Organization']
# ['Doha, Qatar']
# ['Qatarar_fail_and its promises to forgive', 'Qatar', 'Saudi Arabia', 'Al Jazeera', 'Al Arabiya']
# ['Doha', 'Tamim']
# ['Hamad_Ben_Khalifa', 'Hamad_Bn_Jassem', 'Tamim_ Hamad', 'Azmi_Bishara', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Hezbollah', 'Hamdeen_Terrorist Organization', 'Lebanon', 'Gulf', 'Qatar', 'Saudi Arabia', 'Al Arabiya']
# ['Hamdeen_terrorist Organization', 'Saudi Arabia', 'Doha', 'Sharifa', 'The Land of the Two Holy Mosques']
# ['Khashoggi]
# ['Hamdeen_terrorist Organization', 'Qatar', 'Doha', 'Sherifa', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Turkey', 'the black stone', 'the Hamdeen_ terrorist organization', 'honorable', 'Erdogan', 'the mullahs' regime, 'Iran', 'Qatar', 'Saudi Arabia']
# ['Explosion of the gas field of Qatar and Iran', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Kuwait', 'Gulf', 'Al Arabiya', 'Al Jazeera']
# ['Al Jazeera', 'Bahrain', 'Al Hamdeen_Terrorist Organization', 'Gulf', 'Qatar']
# ['The Custodian of the Two Holy Mosques', 'Qatar', 'The Forgiveness Tribe', 'Human Rights', 'Geneva', 'Saudi Arabia', 'Al Arabiya']
# ['Doha', 'Qatar', 'The Gulf']
# ['Hamdeen_ terrorist organization', 'Al-Ghufran tribe', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Qatar', 'Saudi Arabia', 'Riyadh', 'Doha', 'Rights-Forgiveness_in_Qatar']
# ['Qatar', 'The Boycott', 'Hamdeen']
# ['Gulf', 'Iran', 'Al Hamdeen_Terrorist Organization', 'Houthi', 'Turkey', 'Qatar']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Doha', 'Makkah']
# ['Arab Gulf', 'Qatar', 'Saudi Arabia', 'Al Arabiya', 'London', 'Geneva', 'America', 'Tunisia', 'Algeria']
# ['The wife', 'the righteous', 'the women', 'the beautiful', 'the woman', 'the Muslim women']
# ['Trump refuses to receive Tamim', 'Sudan refuses to receive Qatar', 'Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Iran', 'the mullahs' regime', 'Saudi Arabia', 'the Gulf', 'Doha']
# ['Qatar', 'The Second Children', 'The Tragedy of the Second_Children']
# ['Hassan Nasrallah', 'Hezbollah', 'Saudi Arabia', 'The Jews', 'Israel', 'The Hamden_Terrorist Organization', 'Lebanon', 'Qatar', 'Al Arabiya']
# ['Injustice']
# ['Pay the tribute
# ['The Second_Save_Qatar_ Meeting']
# ['The second_saving Qatar meeting', 'Gaddafi_the Gulf']
# ['Jebel Tariq', 'Syria']
# ['Torture of Sheikh Fahd']
# ['Human rights', 'Sheikh Fahad tortured', 'Qatar', 'stoptorture']
# ['Arab boycott', 'Doha', 'Qatar Stock Exchange', 'Qatarelix', 'Qatar_ commits suicide', 'Qatar_fund_terrorism']
# ['BNSports', 'Doha']
# ['Al-Hamdeen Organization', 'Al-Thani', 'Qatarilex', 'Tamim_dozens_Qatar']
# ['human rights']
# ['Hamdeen terrorism', 'Al-Thani', 'Qatarelix', 'Qatar_ commits suicide', 'Qatar_funds_ terrorism']
# ['Human Rights', 'Torture of Sheikh Fahad', 'Qatar']
# ['Iraq']
# ['Arab_ Urgent']
# ['The Boycott', 'Hamdeen', 'Tamim Al-Sham']
# ['Al-Qabail_Qatari', 'Al-Hamdeen', 'Al_Mara', 'Al-Hawajir', 'Al-Bahahi']
# ['Tamim', 'Al-Hamdeen', 'Qatar', 'Qatarelix', 'O-O-Qatar', 'The Meeting of Kabyle_Qahtan']
# ['Infographic', 'Al-Hamdeen Organization', 'Doha']
# ['human rights']
# ['Infographic', 'Qatar', 'Qatarelix', 'Stop_Qatar', 'Qatar_Supports_Terrorism']
# ['Tamim', 'Al-Thani', 'The Orgy of Al-Hamdeen', 'Qatarelix', 'Qatar_Supports_Terrorism']
# ['The Hamdeen Organization', 'Al-Thani']
# ['Qatar']
# ['Iran', 'the mullahs' regime', 'Tamim', 'Hamad_Bn_khalifa', 'Qatar', 'Iraq']
# ['Qatar_National Day', 'Doha', 'Qatar', 'Tameem_Qatar', 'Qatar_Licks']
# ['Talib_Ben_Sharim']
# ['Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt']
# ['Hamdeen_terrorist Organization', 'Yemen', 'Saudi Arabia', 'Emirates', 'Hamdeen']
# ['Tamim', 'Azmi Bishara', 'Sherifa', 'Qimam_Makkah', 'Qatar', 'Saudi Arabia', 'The Emirates', 'Bahrain', 'Egypt']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Kuwait', 'Oman', 'Al Jazeera', 'Al Arabiya']
# ['Salman_Ben_Abdulaziz', “Muhammad_Ben_Salman”, “Mutab_Ben_Abdulaziz”)
# ['Azmi_Bishara', 'Tamim', 'Qatar', 'Hamdeen']
# ['Hamdeen_ terrorist organization', 'honorable', 'al-Houthi', 'Turkey', 'mullahs' regime, 'Iran', 'Qatar', 'Yemen']
# ['Forgiveness', 'Rights-Forgiveness_in_Qatar', 'Saudi Arabia', 'Bahrain', 'Emirates', 'Egypt', 'Al Arabiya']
# ['Hamdeen', 'Blood_cancer']
# ['Saudi Arabia', 'Al-Hamdeen_ terrorist organization', 'Al-Houthi', 'Iran', 'Saudi Arabia-Red Line', 'Al-Houthi_ targets_ the heel of the Muslims']
# ['Qatar', 'Emirates', 'Kuwait', 'Bahrain', 'Oman', 'Egypt', 'Eid_ Al-Adha')
# ['Qatar', 'Corona', 'Tamim']
# ['The Hamdeen_terrorist Organization', 'The International Union of Muslim Scholars', 'Al-Qaradawi', 'The Arab Foundation for Democracy', 'Mozah Al-Musnad', 'Azmi Bishara', 'Saudi Arabia', 'Qatar']
# ['America', 'Qatar', 'Iran', 'Al-Hamdeen_terrorist Organization', 'Sharifa', 'Doha', 'Saudi Arabia']
# ['Doha', 'Qatar', 'Gulf', 'Saudi Arabia']
# ['Hamdeen_terrorist Organization', 'Saudi Arabia', 'Doha', 'Israel', 'Qatar', 'Al Arabiya', 'Jerusalem']
# ['Doha', 'Turkey', 'Al-Hamdeen_terrorist Organization']
# ['Italy', 'Spain', 'Europe', 'China', 'Corona', 'Qatar', 'Doha', 'Erdogan', 'Turkey', 'Tamim']
# ['Qatar', 'Muslims']
# ['Qatar', 'glory orphan', 'good tidings of glory and goodness']
# ['Tamim', 'Qatar', 'Doha', 'Qatar_Supports_Terrorism', 'The Hamdeen Organization']
# ['Palestine issue', 'Middle East', 'Qatar']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Tamim_ben_hammed', 'Azmi_Bishara']
# ['Hamdeen Gang', 'WhatsApp', 'Qatar', 'Azmi_Bishara']
# ['Tamim', 'Libya', 'Egypt', 'Sisi', 'Al-Hamdeen_Terrorist Organization', 'The Brotherhood']
# ['The Kidnapped_ Qataris']
# ['Qatar', 'Al-Hamdeen_ terrorist organization', 'Doha']
# ['Trump', 'Human Rights', 'Qatar', 'Latifa_Musifri', 'Rights_ Forgiveness_in_Qatar', 'Al Hamdeen_Terrorist Organization', 'Al Arabiya']
# ['National_18_December']
# ['Qatar', 'Corona', 'The Gulf', 'Qatar_allies_with_the idiots']
# ['Sabah_Alhamdid', 'Al Jazeera', 'National flags', 'Bahrain', 'Al Hamdeen_Terrorist Organization', 'Qatar']
# ['Hack_citizen_account']
# ['Doha', 'Qatar', 'Hamdeen']
# ['The Second],' Solidarity-With-Forgiveness', 'Forgiveness',' Qatar ']
# ['Al Jazeera', 'Rights of Forgiveness' in Qatar', 'Qatar']
# ['Leave,' Qataris
# ['Qatar', 'Hamdeen_terrorist Organization', 'Iran', 'Saudi Arabia', 'Doha', 'Azmi Bishara', 'Turkey', 'Al Arabiya']
# ['Qatar_System', 'Qatar']
# ['Turkey', 'Al-Hamdeen_Terrorist Organization', 'Libya', 'Qatar', 'The Gulf']
# ['Saudi Arabia', 'Gulf', 'Gulf_Arabia_Mecca', 'Qatar', 'Emirates', 'Bahrain', 'Egypt', 'Al Arabiya', 'Al Jazeera']
# ['Russia', 'Iran', 'the mullahs' regime, 'the Hamdanid terrorist organization', 'Qatar', 'Saudi Arabia']
# ['King Abdulaziz_Camel Festival', 'Qatar', 'Saudi Arabia']
# ['Al-Udeid Base', 'The Middle East', 'Qatar']
# ['Qatar', 'Al Hamdeen_Terrorist Organization', 'Hezbollah', 'Lebanon', 'Iraq']
# ['Qatar', 'Doha', 'Al Jazeera', 'Al Arabiya']
# ['Obama', 'the mullahs' regime', 'Iran', 'the Hamdanid terrorist organization', 'Qatar', 'Saudi Arabia']
# ['Imagination of the Dead', 'Israel', 'Qatar']
# ['Saudi Arabia', 'Qatar', 'Doha']
# ['The Seventh_Injustice_Al_second']
# ['Sheikh Saud_Ben_Jassim_Al_Thani', 'Tamim']
# ['Qatar', 'The seventh year on the injustice of the second_,' Freedom_For the second ']
# ['The seventh year on the injustice of the second _,' The case of the second_]
# ['The eighth year of the injustice of the second year', 'The freedom of the second']
# ['Qatar', 'The Ruling Gang']
# ['Abraha_ Al-Qatari', 'Al-Jazeera']
# ['Mother_claims custody of her son', 'Saud_al_thani', 'Hind Al Qasimi', 'injustice', 'justice', 'Qatar', 'I refuse']
# ['SooudAlThani', 'kidnapped']
# ['Qatar', 'Tamim', 'Doha', 'Doha', 'Qatar', 'Arab Gulf']
# ['Fahd_Al_Thani', 'The Hamdeen Organization', 'Bahrain', 'Qatar', 'Doha', 'Qatar supports terrorism', 'The Qatari regime']
# ['Sheikhs_the second_ honorable', 'Al Hamdeen_ terrorist organization']
# ['Islam']
# ['Iranian']
# ['Bouh_haqaa', 'Saudi Arabia']
# ['The Siege', 'Qatar']
# ['Al-many', 'Qatar']
# ['London']
# ['The second']
# ['the two seas']
# ['New_Year_2020']
# ['Fourth_Bulletin']
# ['Qasim_Araji', 'The Kidnapped_ Qataris', 'The Hashd_shatter_dreams_ of Erdogan', 'Yakim_al Anger']
# ['Saudi Arabia', 'Iran']
# ['King_Salman', 'Prince_Mohammed_Ben_Salman']
# ['National_Emirati_Day_47']
# ['Hamdeen_the terrorist regime']
# ['AlGhofran', 'IOHR']
# ['Why_Qatar', 'Qatar', 'Doha', 'Saudi Arabia', 'The Emirates']
# ['Iran', 'The Hamdeen_ System']
# ['Sudan', 'Libya', 'Iran']
# ['Aid
# ['Majlis Khaled Al-Hail']
# ['King Abdulaziz_Label Festival']
# ['MENA', 'Statelessness', 'WorldConference', 'Statelessness']
# ['Qatar', 'Raise_pricel_price']
# ['Al Thani', 'Qatar', 'The Tragedy of the Second Children']
# ['Tamim', 'Al-Wakrah', 'Qatar']
# ['Al-Houthi', 'Hamad_Ben_Khalifa', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al Jazeera', 'Al Arabiya']
# ['Hamdeen_terrorist Organization', 'Tamim', 'Bahrain', 'Al Hamdeen']
# ['General Leadership', 'Qatar']
# ['Europe', 'Hamdeen_terrorist Organization', 'Italy', 'Qatar']
# ['Iran', 'Tatim-Hamdeen_the terrorist', 'honorable', 'Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al-Jazeera', 'Arab']
# ['Injustice'
# ['Latifa_musifri', 'Al-Hamdeen_terrorist Organization']
# ['Qatar', 'Change Academy', 'Renaissance Forum', 'Arab Democracy Foundation']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Al Arabiya', 'Al Jazeera', 'Iraq', 'Mosul']
# ['Al-Thani', 'Qatar', 'The Gulf', 'Al-Hamdeen_Terrorist Organization', 'London', 'Al-Arabiya', 'Doha']
# ['Iran', 'Qatar', 'Honorable_ turned against_Qatar']
# ['Qatar', 'Human Rights', 'Qatar Prisons']
# ['First Bank of Qatar', 'Al-Hamdeen_Terrorist Organization', 'The Gulf']
# ['The Great Hallaber', 'The Prince_The Beggar']
# ['The meal', 'The Hamdeen organization']
# ['Tamim', 'The Gulf Summit, 40', 'Qatar', 'Saudi Arabia', 'The Gulf', 'Al-Hamdeen_ terrorist organization']
# ['The Custodian of the Two Holy Mosques', 'Salman bin Abdulaziz', 'Muhammad bin Salman', 'The success of the Hajj season 1440', 'Saudi Arabia']
# ['Doha', 'Qatar', 'Corona', 'Tamim']
# ['Hamdeen_terrorist Organization', 'Qatar', 'Doha Gang', 'Sharifa', 'Al Arabiya']
# ['Qatar', 'Saudi Arabia', 'Arabia', 'Al Jazeera', 'Riyadh', 'Emirates', 'Bahrain', 'Egypt']
# ['Qatar', 'Tamim', 'Hamad']
# ['Egypt', 'Hosni_ Mubarak']
# ['Qatar', 'London', 'America', 'Italy', 'Japan', 'Russia', 'Canada', 'Netherlands',' Spain ',' Mauritania ',' Afghanistan ',' India ',' Egypt']
# ['Tamim', 'Al-Udeid base', 'Qatar', 'Al-Hamdeen_ terrorist organization', 'Saudi Arabia', 'Emirates', 'Bahrain', 'Egypt', 'Al-Arabiya']
# ['The Custodian of the Two Holy Mosques', 'Salman bin Abdulaziz', 'Muhammad_ ibn Salman', 'Abdulaziz_ al-Fagham']
# ['Country_ Judiciary']
# ['Previously', 'Fahd_Ben_Abdullah_Al_Thani', 'Celebrating', 'Abdullah_Ben_Fahd_Al_Thani']
# ['Forgiveness', 'Rights_ Forgiveness_Geneva_2018']
# ['Qatar', 'Saud_Al-Qahtani']
# ['Kuwait']
# ['Gaza_UnAttacked']
# ['Sheikh Saud_Ben_Marak_Al_Thani', 'Honorable_Al_Thani']
# ['Arab', 'Doha', 'Qatar']
# ['Saudi Arabia', 'Erdogan']
# ['Iran', 'Corona']
# ['Doha', 'Al-Hamdeen_Terrorist Organization', 'Saudi Arabia', 'Qatar']
# ['World Health Organization']
# ['Narrowing', 'Sadr', 'By God', 'Pleasure', 'Sadness', 'Carefree', 'Grief', 'Qatar', 'Doha']
# ['Muslim_Free_Nohab']
# ['Nidal_Hassan']
# ['Medad_News']
# ['The Custodian of the Two Holy Mosques', 'The Crown Prince']
# ['Turkey']
# ['Ayed_qarni', 'Qatar']
# ['Statement', 'Yemen']
# ['Video', 'Ayed Al-Qarni', 'Qatar', 'Qatar', 'Al-Jazeera']
# ['Medad News', 'Al Sharq']
# ['Medad News', 'Turkey']
# ['Doha', 'World Cup 22', 'Qatar', 'Al Hamdeen_Terrorist Organization', 'The Gulf']
# ['The Hamdeen_terrorist Organization', 'Saudi Arabia', 'Gulf', 'Doha', 'Qatar', 'The promise_qdam_y_tamim']
# ['Saudi Arabia', 'Custodian of the Two Holy Mosques']
# ['Qatar', 'Saudi Arabia', 'The Gulf']
# ['Qatar', 'Al-Hamdeen_Terrorist Organization', 'Doha']
# ['Qatar', 'Qatar Radio', 'Al-Hamdeen_Terrorist Organization']
# ['Rights of Forgiveness in Qatar', 'Government of Qatar']
# ['The island']
# ['The Netherlands', 'Qatar', 'Rights_ Forgiveness_in_Qatar', 'Doha', 'Al Jazeera']
# ['Rights-Forgiveness_in_Qatar', 'Qatar', 'Forgiveness']
# ['The Second', 'Qatar']
# ['COVID19', 'COVID19']
# ['The Arab Summit', 'Tamim' escapes from the summit of Tunisia ']
# ['Sheikh_ Fahd_Ben_Abdullah_Al_Thani', 'Tamim', 'Qatar']
# ['Qatar', 'Istanbul Stock Exchange', 'Arabic']
# ['Fahd_al_ Thani', 'Qatar', 'Terrorism', 'Tamim']
# ['Four Magazine']
# ['Fahd_Al_Thani', 'The Hamdeen Organization', 'Qatar']
# ['Doha', 'Erdogan']
# ['Children of Doha']
# ['Arabic']
# ['Qatari', 'Geneva']
# ['The Constitution is revealed']
# ['Medad News', 'Qatar', 'Tamim', 'The Hamdeen Organization']
# ['Madad News', 'Hamad_Ben_jasim']
# ['Medad News', 'Qatar', 'Qatar_the Godfather of Chaos']
# ['Medad News', 'Qatar', 'Trump']
# ['Sheikh_Mohammed_Ben_Khalifa`,' Sheikh_Ahmed_Ben_Khalifa`, 'The eighth-year_ on the injustice of the second_]
# ['Mubarak_Ben']
# ['The Kingdom', 'Iran']
# ['Foreign_Infographic', 'The Iranian_Regime']
# ['External_Screen', 'Adel_Jubeir', 'Iran']
# ['Fahd
# ['Question_starting_of_the_the_law_posted' ']
# ['Iran', 'Gold']
# ['Khaled_Alhil', 'The Council of Khaled_Alhil']
# ['Forgiveness
# ['Qatar', 'Rights-Forgiveness
# ['Irani', 'Yemen', 'Syria']
# ['Phrase to contemplate', 'Qatar deserves the best of its sons', 'sincere']
# ['The Declaration of the Islamic Caliphate', 'The Soldiers of Egypt']
# ['Arab Summit', 'Qimam_Makkah']
# ['The Gulf Summit', 'The Summits of Makkah']
# ['Iran', 'Iranian_Affairs']
# ['Qassem_Soleimani']
# ['Hamad_Ben_Jassim']
# ['Syria', 'Arabic']
# ['Iran', 'Bahrain']
# ['Iran', 'Banana Republic', 'Kuwait', 'Oman']
# ['Qatar
# ['Newsletter']
# ['Sultan_Ben_Shaim', 'Qatar', 'Al Akhbariya', 'The Kingdom', 'Kabylie_Qahtan' meeting, 'Kabylie_Qahtan']
# ['Qatar', 'News']
# ['The Kingdom', 'News']
# ['Fahd_Al_Thani', 'Al-Hamdeen Organization', 'Hajar', 'Qahtan', 'Al-Akhbariya']
# ['Fahad_Al_Thani', 'The Kabyle_Qahtan meeting', 'The Hamdeen Organization']
# ['Fahad_Al_Thani', 'Tamim', 'The Hamdeen Organization', 'Qatar']
# ['Ankara', 'Qatar', 'Al-Akhbariya']
# ['Fahad_Al_Thani', 'The Kabyle_Qahtan meeting', 'The Hamdeen Organization', 'Hajar', 'Qahtan']
# ['Fahad_Al_Thani', 'Tamim', 'Qatar']
# ['News', 'Al-Jubeir', 'The Kingdom']
# ['The Kingdom', 'Qatar', 'News']
# ['Qatar', 'Al-Hilal_ Al-Rayan', 'Qatar']
# ['Forgiveness
# ['Rights of Forgiveness_in_Qatar', 'Qatar', 'Al Jazeera']
# ['Arab Landscape', 'Fahd_Ben_Abdullah']
# ['Arab_Mashhad']
# ['Libya']
# ['Fahd_Al_Thani', 'Tamim', 'The Hamdeen Organization', 'Qatar', 'Qatar']
# ['We avenged the Messenger', 'Paris', 'Islamic State', 'IslamicState', 'ParisShooting', 'parisisburning', 'CharlieHebd']
# ['Fahd_al_tani', 'Terrorism', 'Al-Akhbariya']
# ['Fahd_al_thani']
# ['Qatar', 'News', 'Hajj_salam_salam']
# ['Sultan_Ben_Shaim', 'Kabyle_Qahtan', 'Qatar', 'News']
# ['Fahd_al_thani', 'al-Hamdeen organization', 'al-Akhbariya', 'Kabylie_qahtan']
# ['The Hamdeen Organization', 'London_ Refuses_Tameem']
# ['Video', 'Qatar', 'Al-Hamdeen Organization']
# ['Video', 'Qatar', 'Rights_ Forgiveness_in_Qatar', 'The Hamdeen Organization']
# ['What_hide_the greatest_yaqatar']
# ['Sharjah', 'Ramadan']
# ['Iran', 'Persians', 'Saudi Arabia', 'Iraq', 'Kuwait', 'Egypt', 'Emirates', 'The Hamdeen Organization']
# ['Map_News']
# ['Diameter', 'long_value']
# ['Qatar', 'Majlis Khalid Al-Hail']
# ['Ghufran', 'iBelong', 'Brazil', 'MahaMamo']
# ['Forgiveness-in-the-Hague', 'Rights-Forgiveness-in-Qatar', 'Doha', 'Qatar']
# ['Netherlands']
# [“Rights
# ['Rights
# ['Shahid', 'Asadi', 'Hezbollah', 'Lebanon']
# ['Qatar', 'Al Jazeera', 'What is the greatest', 'The boycott states']
# ['Forgiveness-in-the-Hague', 'Qatar', 'Rights-Forgiveness-in-Qatar']
# ['Muhammad_Kahle_Prisoner_Rai', 'Qatar']
# ['The Hague', 'Rights to Forgiveness' in Qatar', 'Doha', 'Qatar', 'Al Jazeera']
# ['لاهاي']
# ['Sheikh Fahad_By Forgiveness Ceremony', 'Qatar']
# ['Mohammed bin Salman']
# ['Al-Quds Summit']
# ['Iraq', 'Baghdad']
# ['Joint Gulf_shield_1']
# ['Al-Furqan Foundation', 'Salil_ Al-Sawarim_4', 'On the Methodology of Prophethood', 'Caliphate']
# ['The Hague', 'Rights_ Forgiveness_in_Qatar', 'Qatar']
# ['The Hague', 'Rights_ Forgiveness_in_Qatar']
# ['Meeting of Kabyle Qahtan']
# ['Qatar', 'The Hamdeen Organization']
# ['Islamic State', 'ISIS', 'Salil_Aswarim_5']
# ['Iran', 'Qatar', 'Soleimani']
# ['Ain_ Al-Asad', 'Iraq', 'Iran', 'American_base']
# ['Burma']
# ['Okaz', 'Hamad_Bn_Khalifa', 'Saudi Arabia']
# ['Okaz']
# ['Qatar', 'Saudi Arabia', 'Emirates', 'Bahrain']
# ['Okaz', 'To be first', 'Al Hamdeen Organization', 'Qatar', 'Doha']
# ['Libyan Army', 'Haftar', 'Turkey']
# ['Talal_al-Mihoub', 'Turkey', 'Tripoli']
# ['To be first', 'Iran', 'Ukrainian plane']
# ['Khamenei', 'Sana'a', 'Terrorism', 'To be_first', 'Arab_Alliance']
# ['Saudi Falcons and Fishing Exhibition 2', 'Saudi Arabia']
# ['Forgiveness',' Rights of Forgiveness' in Qatar ']
# ['Qatar', 'Al-Thani', 'Okaz']
# ['Okaz', 'Al-Hamdeen', 'Organization of Al-Hamdeen_ robbed of the property of Qataris', 'Ajel', 'Okaz']
# ['Okaz', 'Al Hamdeen', 'To be_first']
# ['Qatar', 'Okaz', 'Be_first', 'The Hamdeen Organization', 'Doha']
# ['Get back now', 'Qatar Central Bank']
# ['Oil']
# ['The banner incites the twitterers']
# ['Fahad_Al_Thani', 'Al-Hamdeen Organization', 'Qatar', 'Qatarelix']
# ['Country_System', 'Watch_Sky']
# ['Geneva', 'Watch_sky']
# ['Watch_sky']
# ['Anonymous', 'Op Sudan', 'Sudan Protests']
# ['Rights-Forgiveness_in_Qatar', 'Doha', 'Qatar']
# ['Qatar', 'Rights_ Forgiveness_in_Qatar', 'Doha', 'Al Jazeera']
# ['United State']
# ['Armed Forces', 'Qatar']
# ['Saudi']
# ['King Abdulaziz_Label Festival', 'Qatar']
# ['Istanbul']
# ['Saudi Arabia', 'The Kingdom']
# ['Britain']
# ['Tamim', 'Qatar', 'Al-Hamdeen', 'Qatarelix', 'Stop_Qatar']
# ['Torture of Sheikh Fahad', 'Qatar', 'Torture']
# ['Qatar_banks', 'Qatarelix', 'Qatar_ commits suicide', 'Qatar_finance_terrorism']
# ['Qatar', 'Qatar_banking System']
# ['Iran', 'UAE', 'Saudi Arabia', 'Kuwait', 'Bahrain']
# ['Facts_in_Minutes', 'Hamad_Bn_jasim', 'Israel']
# ['Tamim_Majdoom', 'Kaaba_magdoom']
# ['The Hamdeen Organization', 'The Treachery of the Neighbor']
# ['Qatari opposition']
# 73041                                 [['قطري',, 'العمرة']]
# 73064        [['تنظيم_الحمدين',, 'منع_القطريين_من_العمرة']]
# 73065     [['قطري',, 'المقاطعة',, 'الخليج',, 'تنظيم_الحم...
# 73066     [['تنظيم_الحمدين_الارهابي',, 'السعوديه_العظمى'...
# 73067             [['الغفران',, 'لقاء_فهد_ال_ثاني_بتويتر']]
#                                 ...
# 219684                    [['تميم_المجد',, 'كعبة_المضيوم']]
# 220021                    [['تنظيم_الحمدين',, 'غدر_الجار']]
# 220065                                            [['قطر']]
# 220114                                            [['قطر']]
# 220193                               [['المعارضة_القطرية']]
# Name: hashtags, Length: 1227, dtype: object

# %%
#Identifying the most liked, retweeted, 
retweets = profile[['tweet_time','tweet_text','retweet_count','like_count','quote_count','reply_count','hashtags']]

retweets = retweets[n_empty]


top_retweet = retweets.sort_values(by=['retweet_count'],ascending=False).head(1)

top_like= retweets.sort_values(by=['like_count'],ascending=False).head(1)

top_quote= retweets.sort_values(by=['quote_count'],ascending=False).head(1)

top_reply= retweets.sort_values(by=['reply_count'],ascending=False).head(1)


#top_retweet
print("\ntop retweet\n",top_retweet[['hashtags','retweet_count']],"\n")
print("Translation: General Leadership ,Qatar")

print("\ntop like\n",top_like[['hashtags','like_count']],"\n")

print("Translation: General leadership , Qatar '")

print("\ntop quote\n",top_like[['hashtags','quote_count']],"\n")

print("Translation: General leadership , Qatar '")

print("\ntop reply\n",top_like[['hashtags','reply_count']],"\n")

print("Translation: General leadership , Qatar '")


#top retweeted tweet

t_tweet = top_retweet[['tweet_time','tweet_text']].to_string()

print("\ntop retweeted tweet: \n",t_tweet)
# Out:
# top retweet
#                           hashtags  retweet_count
# 171842  ['القياده_العامه', 'قطر']           4289
#
# Translation: General Leadership ,Qatar
#
# top like
#                           hashtags  like_count
# 171842  ['القياده_العامه', 'قطر']        4571
#
# Translation: General leadership , Qatar '
#
# top quote
#                           hashtags  quote_count
# 171842  ['القياده_العامه', 'قطر']          202
#
# Translation: General leadership , Qatar '
#
# top reply
#                           hashtags  reply_count
# 171842  ['القياده_العامه', 'قطر']          506
#
# Translation: General leadership , Qatar '
#
# top retweeted tweet:
#                tweet_time                                                                                                                                                                  tweet_text
# 171842  2020-05-06 19:52  تصاعد أدخنة من مبنى #القياده_العامه للجيش في #قطر.\nوزارة الداخلية وتلفزيون قطر وقناة الجزيرة والشيراتون و المخابرات قريبة جدًا من هذا المبنى. (؟) https://t.co/pixdMwIOvh

# %%
'''Export of all data used in dataset'''

#final.to_csv('original_data_combined.csv')
#copy.to_csv('final_dataset.csv')
#top_20_months.to_csv('topmonthyear.csv')
